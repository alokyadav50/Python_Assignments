# %%
(Q1.) In the below elements which of them are values or an expression? 
eg:- values can be integer or string and expressions will be mathematical operators.

* 
'hello'
-87.8
- 
/ 
+	
6 

Answer= 1)Here 'hello' is an string and 6 is in interger format so it represents a values.
  2) *,-,/,+ represents an expression.

# %%
(Q2.) What is the difference between string and variable?

String-strings are immutable data type that is we can't change one string at a time.
if we want to access the string we can do it through indexing.
indexing of string starts with 0.
 
Variable-we can store the string in a variable.
In a variable we can store multible strings at a time.
when a string stored in variable one memory address is allocated to that string through that we can access that string.
In Python we don't need to declare a variable name.

# %%
(Q3) Describe three different data types.

Integer-if we get output in the form of whole value then that will be intger data type. eg-3

Float-if we get output in decimal format then that represents floating point number. eg-32.3

String-We can represents the strings in "".
strings are immutable data type that is we can't change one string at a time.
if we want to access the string we can do it through indexing.
indexing of string starts with 0.
eg of string "Hello"

# %%
(Q4)What is an expression made up of? What do all expressions do?

An expression contains real and imaginary values.
Eg- 2+8j
expressions perform mathemaical operations like +,-,*,/,==,+= etc.

# %%
(Q5)This assignment statements, like spam = 10. What is the difference between an expression and a statement?

Here we are assigning value 10 to spam if it was  in expression format like spam==10 then we are comparing 10 with spam.

# %%
(Q6)After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

bcon=23

# %%
(Q7) . What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3
(i)'spamspamspam'
(II)'spamspamspam'

# %%
(Q8) Why is eggs a valid variable name while 100 is invalid?
eggs represents a unique name that's why it's a valid variable name while 100 represents a memory location 
that's why it's invaild variable name.

# %% [markdown]
# (Q9)What three functions can be used to get the integer, floating-point number, or string
# version of a value?
#
# Ans) int(),float() and str() function is used to get the integer, floating-point number, or string
# version of a value?

# %%
(Q10) Why does this expression cause an error? How can you fix it?
'I have eaten'+99+'burritos.'
convert 99 into str(99) to fix the error
'I have eaten'+str(99)+'burritos.'
